# %% [markdown]
# ## Importing and Formatting the Data

# %%
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist

# Keras has already split the data into training and test data
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# Training images is a list of 60,000 2D lists.
# Each 2D list is 28 by 28—the size of the MNIST pixel data.
# Each item in the 2D array is an integer from 0 to 255 representing its grayscale
# intensity where 0 means white, 255 means black.
print(len(training_images), training_images[0].shape)

# training_labels are a value between 0 and 9 indicating which digit is represented.
# The first item in the training data is a 5
print(len(training_labels), training_labels[0])
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\dlenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 60000 (28, 28)
# 60000 5

# %%
# Visualizes the first 100 images from the dataset
for i in range(100):
    ax = plt.subplot(10, 10, i+1)
    ax.axis('off')
    plt.imshow(training_images[i], cmap='Greys')

# %% [markdown]
# ## Fixing the Data Format, from 2D to 1D

# %%
from tensorflow.keras.utils import to_categorical

# Preparing the dataset
# Setup train and test splits
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()


# 28 x 28 = 784, because that's the dimensions of the MNIST data.
image_size = 784

# Reshaping the training_images and test_images to lists of vectors with length 784
# instead of lists of 2D arrays. Same for the test_images
training_data = training_images.reshape(training_images.shape[0], image_size) 
test_data = test_images.reshape(test_images.shape[0], image_size)

# [
#     [1,2,3]
#     [4,5,6]
# ]

# => [1,2,3,4,5,6]

# Just showing the changes...
print("training data: ", training_images.shape, " ==> ", training_data.shape)
print("test data: ", test_images.shape, " ==> ", test_data.shape)
# Out:
# training data:  (60000, 28, 28)  ==>  (60000, 784)
# test data:  (10000, 28, 28)  ==>  (10000, 784)

# %%
# Create 1-hot encoded vectors using to_categorical
num_classes = 10 # Because it's how many digits we have (0-9) 

# to_categorical takes a list of integers (our labels) and makes them into 1-hot vectors
training_labels = to_categorical(training_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %% [markdown]
# ## Building the Deep Neural Network
# 3 layers—the input layer, a single hidden layer, and the output layer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Sequential models are a series of layers applied linearly.
model = Sequential()

# The first layer must specify it's input_shape.
# This is how the first two layers are added, the input layer and the hidden layer.
model.add(Dense(units=680, activation='relu', input_shape=(image_size,)))

# This is how the output layer gets added, the 'softmax' activation function ensures
# that the sum of the values in the output nodes is 1. Softmax is very
# common in classification networks. 
model.add(Dense(units=num_classes, activation='softmax'))

# This function provides useful text data for our network
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 680)               533800
#
#  dense_5 (Dense)             (None, 10)                6810
#
# =================================================================
# Total params: 540610 (2.06 MB)
# Trainable params: 540610 (2.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compiling and Training a Model

# %%
# sgd stands for stochastic gradient descent.
# categorical_crossentropy is a common loss function used for categorical classification.
# accuracy is the percent of predictions that were correct.
model.compile(optimizer="rmsprop", loss='categorical_crossentropy', metrics=['accuracy'])

# The network will make predictions for 128 flattened images per correction.
# It will make a prediction on each item in the training set 1 times (1 epochs)
# And 10% of the data will be used as validation data.
history = model.fit(training_data, training_labels, batch_size=128, epochs=40, verbose=True, validation_split=.1)
# Out:
# Epoch 1/40
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\dlenv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\dlenv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 422/422 [==============================] - 2s 3ms/step - loss: 5.7031 - accuracy: 0.8994 - val_loss: 0.8018 - val_accuracy: 0.9525
# Epoch 2/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.7082 - accuracy: 0.9540 - val_loss: 1.0547 - val_accuracy: 0.9445
# Epoch 3/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.5269 - accuracy: 0.9654 - val_loss: 0.8566 - val_accuracy: 0.9578
# Epoch 4/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.4090 - accuracy: 0.9725 - val_loss: 0.7933 - val_accuracy: 0.9603
# Epoch 5/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.3247 - accuracy: 0.9766 - val_loss: 0.8512 - val_accuracy: 0.9607
# Epoch 6/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.3121 - accuracy: 0.9792 - val_loss: 0.7195 - val_accuracy: 0.9718
# Epoch 7/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2540 - accuracy: 0.9827 - val_loss: 0.9277 - val_accuracy: 0.9677
# Epoch 8/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2499 - accuracy: 0.9846 - val_loss: 0.8780 - val_accuracy: 0.9720
# Epoch 9/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2453 - accuracy: 0.9852 - val_loss: 0.8370 - val_accuracy: 0.9758
# Epoch 10/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2252 - accuracy: 0.9866 - val_loss: 0.8733 - val_accuracy: 0.9752
# Epoch 11/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1961 - accuracy: 0.9885 - val_loss: 0.9543 - val_accuracy: 0.9735
# Epoch 12/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1854 - accuracy: 0.9896 - val_loss: 0.9686 - val_accuracy: 0.9742
# Epoch 13/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.2078 - accuracy: 0.9892 - val_loss: 0.9712 - val_accuracy: 0.9748
# Epoch 14/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1793 - accuracy: 0.9911 - val_loss: 0.9686 - val_accuracy: 0.9760
# Epoch 15/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1670 - accuracy: 0.9910 - val_loss: 0.8972 - val_accuracy: 0.9777
# Epoch 16/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1564 - accuracy: 0.9920 - val_loss: 1.0189 - val_accuracy: 0.9767
# Epoch 17/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1536 - accuracy: 0.9920 - val_loss: 1.0103 - val_accuracy: 0.9755
# Epoch 18/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1353 - accuracy: 0.9930 - val_loss: 1.0153 - val_accuracy: 0.9757
# Epoch 19/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1308 - accuracy: 0.9934 - val_loss: 1.1262 - val_accuracy: 0.9747
# Epoch 20/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1140 - accuracy: 0.9937 - val_loss: 1.1200 - val_accuracy: 0.9767
# Epoch 21/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1056 - accuracy: 0.9944 - val_loss: 1.0656 - val_accuracy: 0.9765
# Epoch 22/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1223 - accuracy: 0.9940 - val_loss: 1.1282 - val_accuracy: 0.9788
# Epoch 23/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1231 - accuracy: 0.9944 - val_loss: 1.2290 - val_accuracy: 0.9750
# Epoch 24/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0992 - accuracy: 0.9951 - val_loss: 1.1244 - val_accuracy: 0.9800
# Epoch 25/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1027 - accuracy: 0.9949 - val_loss: 1.2393 - val_accuracy: 0.9780
# Epoch 26/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1016 - accuracy: 0.9954 - val_loss: 1.0456 - val_accuracy: 0.9795
# Epoch 27/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0791 - accuracy: 0.9958 - val_loss: 1.1457 - val_accuracy: 0.9788
# Epoch 28/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0970 - accuracy: 0.9955 - val_loss: 1.2694 - val_accuracy: 0.9787
# Epoch 29/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0910 - accuracy: 0.9953 - val_loss: 1.2607 - val_accuracy: 0.9790
# Epoch 30/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0772 - accuracy: 0.9963 - val_loss: 1.2253 - val_accuracy: 0.9810
# Epoch 31/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0714 - accuracy: 0.9965 - val_loss: 1.1491 - val_accuracy: 0.9823
# Epoch 32/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0844 - accuracy: 0.9960 - val_loss: 1.1791 - val_accuracy: 0.9788
# Epoch 33/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0670 - accuracy: 0.9966 - val_loss: 1.2255 - val_accuracy: 0.9818
# Epoch 34/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0664 - accuracy: 0.9966 - val_loss: 1.2893 - val_accuracy: 0.9795
# Epoch 35/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0715 - accuracy: 0.9967 - val_loss: 1.2394 - val_accuracy: 0.9808
# Epoch 36/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0611 - accuracy: 0.9969 - val_loss: 1.3773 - val_accuracy: 0.9783
# Epoch 37/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0568 - accuracy: 0.9973 - val_loss: 1.3972 - val_accuracy: 0.9807
# Epoch 38/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0845 - accuracy: 0.9963 - val_loss: 1.2916 - val_accuracy: 0.9818
# Epoch 39/40
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0780 - accuracy: 0.9969 - val_loss: 1.1863 - val_accuracy: 0.9807
# Epoch 40/40
# 137/422 [========>.....................] - ETA: 0s - loss: 0.0584 - accuracy: 0.9971

# %% [markdown]
# ## Evaluating the Model

# %%
loss, accuracy = model.evaluate(test_data, test_labels, verbose=True)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3408 - accuracy: 0.9606
# Test loss: 0.341
# Test accuracy: 0.961

# %% [markdown]
# ## Analyzing the Results

# %%
from numpy import argmax

# Predicting once, then we can use these repeatedly in the next cell without recomputing the predictions.
predictions = model.predict(test_data)

# For pagination & style in second cell
page = 0
fontdict = {'color': 'black'}
# Out:
# 313/313 [==============================] - 0s 919us/step

# %%
# Repeatedly running this cell will page through the predictions
for i in range(16):
    ax = plt.subplot(4, 4, i+1)
    ax.axis('off')
    plt.imshow(test_images[i + page], cmap='Greys')
    prediction = argmax(predictions[i + page])
    true_value = argmax(test_labels[i + page])

    fontdict['color'] = 'black' if prediction == true_value else 'red'
    plt.title("{}, {}".format(prediction, true_value), fontdict=fontdict)

page += 16
plt.tight_layout()
plt.show()
