# %% [markdown]
# ## Importing and Formatting the Data

# %%
# For drawing the MNIST digits as well as plots to help us evaluate performance we
# will make extensive use of matplotlib
from matplotlib import pyplot as plt

# All of the Keras datasets are in keras.datasets
from tensorflow.keras.datasets import mnist

# Keras has already split the data into training and test data
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# Training images is a list of 60,000 2D lists.
# Each 2D list is 28 by 28—the size of the MNIST pixel data.
# Each item in the 2D array is an integer from 0 to 255 representing its grayscale
# intensity where 0 means white, 255 means black.
print(len(training_images), training_images[0].shape)

# training_labels are a value between 0 and 9 indicating which digit is represented.
# The first item in the training data is a 5
print(len(training_labels), training_labels[0])
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\envs\dlenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 60000 (28, 28)
# 60000 5

# %%
# Lets visualize the first 100 images from the dataset
for i in range(100):
    ax = plt.subplot(10, 10, i+1)
    ax.axis('off')
    plt.imshow(training_images[i], cmap='Greys')

# %% [markdown]
# ## Fixing the Data Format, from 2D to 1D

# %%
from tensorflow.keras.utils import to_categorical

# Preparing the dataset
# Setup train and test splits
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()


# 28 x 28 = 784, because that's the dimensions of the MNIST data.
image_size = 784

# Reshaping the training_images and test_images to lists of vectors with length 784
# instead of lists of 2D arrays. Same for the test_images
training_data = training_images.reshape(training_images.shape[0], image_size) 
test_data = test_images.reshape(test_images.shape[0], image_size)

# [
#     [1,2,3]
#     [4,5,6]
# ]

# => [1,2,3,4,5,6]

# Just showing the changes...
print("training data: ", training_images.shape, " ==> ", training_data.shape)
print("test data: ", test_images.shape, " ==> ", test_data.shape)
# Out:
# training data:  (60000, 28, 28)  ==>  (60000, 784)
# test data:  (10000, 28, 28)  ==>  (10000, 784)

# %%
# Create 1-hot encoded vectors using to_categorical
num_classes = 10 # Because it's how many digits we have (0-9) 

# to_categorical takes a list of integers (our labels) and makes them into 1-hot vectors
training_labels = to_categorical(training_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %% [markdown]
# ## Building the Deep Neural Network
# 3 layers—the input layer, a single hidden layer, and the output layer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Sequential models are a series of layers applied linearly.
model = Sequential()

# The first layer must specify it's input_shape.
# This is how the first two layers are added, the input layer and the hidden layer.
model.add(Dense(units=128, activation='sigmoid', input_shape=(image_size,)))

# This is how the output layer gets added, the 'softmax' activation function ensures
# that the sum of the values in the output nodes is 1. Softmax is very
# common in classification networks. 
model.add(Dense(units=num_classes, activation='softmax'))

# This function provides useful text data for our network
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 128)               100480
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compiling and Training a Model

# %%
# sgd stands for stochastic gradient descent.
# categorical_crossentropy is a common loss function used for categorical classification.
# accuracy is the percent of predictions that were correct.
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])

# The network will make predictions for 128 flattened images per correction.
# It will make a prediction on each item in the training set 5 times (5 epochs)
# And 10% of the data will be used as validation data.
history = model.fit(training_data, training_labels, batch_size=128, epochs=40, verbose=True, validation_split=.1)
# Out:
# Epoch 1/40
# 422/422 [==============================] - 1s 2ms/step - loss: 1.0339 - accuracy: 0.7286 - val_loss: 0.5567 - val_accuracy: 0.8870
# Epoch 2/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.5233 - accuracy: 0.8757 - val_loss: 0.3905 - val_accuracy: 0.9103
# Epoch 3/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.4177 - accuracy: 0.8949 - val_loss: 0.3295 - val_accuracy: 0.9237
# Epoch 4/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.3642 - accuracy: 0.9052 - val_loss: 0.2934 - val_accuracy: 0.9270
# Epoch 5/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.3323 - accuracy: 0.9126 - val_loss: 0.2707 - val_accuracy: 0.9317
# Epoch 6/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.3064 - accuracy: 0.9170 - val_loss: 0.2583 - val_accuracy: 0.9322
# Epoch 7/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2866 - accuracy: 0.9228 - val_loss: 0.2407 - val_accuracy: 0.9387
# Epoch 8/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2699 - accuracy: 0.9262 - val_loss: 0.2317 - val_accuracy: 0.9413
# Epoch 9/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2577 - accuracy: 0.9290 - val_loss: 0.2191 - val_accuracy: 0.9415
# Epoch 10/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2470 - accuracy: 0.9317 - val_loss: 0.2140 - val_accuracy: 0.9440
# Epoch 11/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2360 - accuracy: 0.9349 - val_loss: 0.2059 - val_accuracy: 0.9450
# Epoch 12/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2283 - accuracy: 0.9370 - val_loss: 0.1988 - val_accuracy: 0.9475
# Epoch 13/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2197 - accuracy: 0.9394 - val_loss: 0.1957 - val_accuracy: 0.9492
# Epoch 14/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2151 - accuracy: 0.9412 - val_loss: 0.1897 - val_accuracy: 0.9498
# Epoch 15/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2068 - accuracy: 0.9425 - val_loss: 0.1849 - val_accuracy: 0.9513
# Epoch 16/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.2008 - accuracy: 0.9446 - val_loss: 0.1783 - val_accuracy: 0.9527
# Epoch 17/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1946 - accuracy: 0.9464 - val_loss: 0.1751 - val_accuracy: 0.9532
# Epoch 18/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1899 - accuracy: 0.9482 - val_loss: 0.1731 - val_accuracy: 0.9552
# Epoch 19/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1840 - accuracy: 0.9492 - val_loss: 0.1708 - val_accuracy: 0.9535
# Epoch 20/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.9513 - val_loss: 0.1629 - val_accuracy: 0.9557
# Epoch 21/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1738 - accuracy: 0.9529 - val_loss: 0.1634 - val_accuracy: 0.9565
# Epoch 22/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1704 - accuracy: 0.9541 - val_loss: 0.1614 - val_accuracy: 0.9583
# Epoch 23/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1676 - accuracy: 0.9546 - val_loss: 0.1598 - val_accuracy: 0.9563
# Epoch 24/40
# 422/422 [==============================] - 1s 2ms/step - loss: 0.1639 - accuracy: 0.9559 - val_loss: 0.1564 - val_accuracy: 0.9583
# Epoch 25/40
# 422/422 [==============================] - 1s 2ms/step - loss: 0.1605 - accuracy: 0.9571 - val_loss: 0.1548 - val_accuracy: 0.9575
# Epoch 26/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1555 - accuracy: 0.9574 - val_loss: 0.1532 - val_accuracy: 0.9583
# Epoch 27/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1541 - accuracy: 0.9585 - val_loss: 0.1505 - val_accuracy: 0.9592
# Epoch 28/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1498 - accuracy: 0.9600 - val_loss: 0.1499 - val_accuracy: 0.9602
# Epoch 29/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1475 - accuracy: 0.9606 - val_loss: 0.1478 - val_accuracy: 0.9605
# Epoch 30/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1450 - accuracy: 0.9612 - val_loss: 0.1450 - val_accuracy: 0.9618
# Epoch 31/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1435 - accuracy: 0.9611 - val_loss: 0.1468 - val_accuracy: 0.9590
# Epoch 32/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1427 - accuracy: 0.9616 - val_loss: 0.1454 - val_accuracy: 0.9580
# Epoch 33/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1395 - accuracy: 0.9622 - val_loss: 0.1418 - val_accuracy: 0.9617
# Epoch 34/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1370 - accuracy: 0.9636 - val_loss: 0.1427 - val_accuracy: 0.9608
# Epoch 35/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1352 - accuracy: 0.9636 - val_loss: 0.1416 - val_accuracy: 0.9605
# Epoch 36/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1303 - accuracy: 0.9651 - val_loss: 0.1382 - val_accuracy: 0.9628
# Epoch 37/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1272 - accuracy: 0.9659 - val_loss: 0.1382 - val_accuracy: 0.9612
# Epoch 38/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1267 - accuracy: 0.9658 - val_loss: 0.1382 - val_accuracy: 0.9607
# Epoch 39/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1224 - accuracy: 0.9680 - val_loss: 0.1372 - val_accuracy: 0.9633
# Epoch 40/40
# 422/422 [==============================] - 1s 1ms/step - loss: 0.1224 - accuracy: 0.9676 - val_loss: 0.1363 - val_accuracy: 0.9603

# %% [markdown]
# ## Evaluating the Model

# %%
loss, accuracy = model.evaluate(test_data, test_labels, verbose=True)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
# Out:
# 313/313 [==============================] - 0s 919us/step - loss: 0.1569 - accuracy: 0.9521
# Test loss: 0.157
# Test accuracy: 0.952

# %% [markdown]
# ## Analyze Results

# %%
from numpy import argmax

# Predicting once, then we can use these repeatedly in the next cell without recomputing the predictions.
predictions = model.predict(test_data)

# For pagination & style in second cell
page = 0
fontdict = {'color': 'black'}
# Out:
# 313/313 [==============================] - 0s 753us/step

# %%
# Repeatedly running this cell will page through the predictions
for i in range(16):
    ax = plt.subplot(4, 4, i+1)
    ax.axis('off')
    plt.imshow(test_images[i + page], cmap='Greys')
    prediction = argmax(predictions[i + page])
    true_value = argmax(test_labels[i + page])

    fontdict['color'] = 'black' if prediction == true_value else 'red'
    plt.title("{}, {}".format(prediction, true_value), fontdict=fontdict)

page += 16
plt.tight_layout()
plt.show()
